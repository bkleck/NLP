# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn

# %%
df = pd.read_csv('BDL Feedback 31 May 2020.csv')
df
# Out:
#                               Agency Agency_short(HR Pulse) Department  \
# 0          Housing Development Board                    HDB
# 1          Housing Development Board                    HDB
# 2          Housing Development Board                    HDB
# 3                              Vital                    MOF
# 4          Housing Development Board                    HDB
# ...                              ...                    ...        ...
# 172598         Civil Service College                    CSC        LFG
# 172599  Government Technology Agency                GOVTECH
# 172600  Government Technology Agency                GOVTECH
# 172601         Civil Service College                    CSC        LFG
# 172602         Civil Service College                    CSC        DLS
#
#                             Job Function          Imported Designation  \
# 0                                    NaN   Hg Administrative Executive
# ...

# %%
# drop irrelevant columns
df.drop(columns=['Department', 'Job Function', 'Imported Designation','Updated Designation', 'Course Domain', 'CourseID','Rated Date Time (SGT)'],inplace=True)
df.head()
# Out:
#                       Agency Agency_short(HR Pulse)  \
# 0  Housing Development Board                    HDB
# 1  Housing Development Board                    HDB
# 2  Housing Development Board                    HDB
# 3                      Vital                    MOF
# 4  Housing Development Board                    HDB
#
#                                                  Tag  \
# 0  Basic Digital Literacy: Cyber Security,Prototy...
# 1                            Prototype Testing Space
# 2  (BDLCD) Basic Digital Literacy: Cyber & Data S...
# 3  Basic Digital Literacy: Cyber Security,Prototy...
# 4  Basic Digital Literacy: Cyber Security,Prototy...
#
#                          Course Name  Rating                      Comment
# 0  BDLQ1: Cyber & Data Security Quiz       5  Awareness on Cyber Security
# 1            BDLCD2: Data Security         5                          NaN
# 2            BDLCD1: Cyber Security        5                          NaN
# ...

# %%
## rename columns
df.rename({'Agency': 'agency', 'Agency_short(HR Pulse)': 'agency_short', 'Tag': 'tag', 'Course Name': 'course', 'Rating': 'rating', 'Comment': 'comment'}, axis=1, inplace=True)
df.head()
# Out:
#                       agency agency_short  \
# 0  Housing Development Board          HDB
# 1  Housing Development Board          HDB
# 2  Housing Development Board          HDB
# 3                      Vital          MOF
# 4  Housing Development Board          HDB
#
#                                                  tag  \
# 0  Basic Digital Literacy: Cyber Security,Prototy...
# 1                            Prototype Testing Space
# 2  (BDLCD) Basic Digital Literacy: Cyber & Data S...
# 3  Basic Digital Literacy: Cyber Security,Prototy...
# 4  Basic Digital Literacy: Cyber Security,Prototy...
#
#                               course  rating                      comment
# 0  BDLQ1: Cyber & Data Security Quiz       5  Awareness on Cyber Security
# 1            BDLCD2: Data Security         5                          NaN
# 2            BDLCD1: Cyber Security        5                          NaN
# 3  BDLQ1: Cyber & Data Security Quiz       3                          NaN
# ...

# %%
## drop optional modules
df = df[~df.course.str.contains("Optional")]

# %%
## drop quizzes
df = df[~df.course.str.contains("Quiz")]

# %% [markdown]
# # Take out specific Tags for shuffling to label

# %% [markdown]
# ## 1. Communication & Collaboration

# %%
from sklearn.utils import shuffle

# %%
cc = df[df.course.str.contains("BDLCC")]
cc
# Out:
#                                      agency agency_short  \
# 81      Immigration & Checkpoints Authority          MHA
# 83      Immigration & Checkpoints Authority          MHA
# 89      Immigration & Checkpoints Authority          MHA
# 109                     Ministry of Defence       MINDEF
# 114                     Ministry of Defence       MINDEF
# ...                                     ...          ...
# 156924            Housing Development Board          HDB
# 156927                 People's Association           PA
# 157060              Public Service Division          PSD
# 157061              Public Service Division          PSD
# 157063              Public Service Division          PSD
#
#                                                                   tag  \
# 81      (BDLCC) Basic Digital Literacy: Communication & Collaboration
# 83      (BDLCC) Basic Digital Literacy: Communication & Collaboration
# ...

# %%
## drop rows with empty comments
cc.dropna(subset=['comment'], inplace=True)
cc
# Out:
# C:\Users\Boon Kong\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      agency agency_short  \
# 81      Immigration & Checkpoints Authority          MHA
# 118             National Environment Agency          NEA
# 119             National Environment Agency          NEA
# 451                       Singapore Customs          MOF
# 452     Immigration & Checkpoints Authority          MHA
# ...                                     ...          ...
# 156898                Civil Service College          CSC
# 156899                Civil Service College          CSC
# 156922                  Temasek Polytechnic           TP
# 156923                  Temasek Polytechnic           TP
# ...

# %%
# shuffle the data to randomize it
shuffled = shuffle(cc)
shuffled.reset_index(inplace=True, drop=True)
shuffled.head()
# Out:
#                                   agency agency_short  \
# 0       Ministry of Defence Headquarters       MINDEF
# 1            National Environment Agency          NEA
# 2       Ministry of Defence Headquarters       MINDEF
# 3                   National Parks Board       NPARKS
# 4  Inland Revenue Authority Of Singapore         IRAS
#
#                                                              tag  \
# 0  (BDLCC) Basic Digital Literacy: Communication & Collaboration
# 1  (BDLCC) Basic Digital Literacy: Communication & Collaboration
# 2  (BDLCC) Basic Digital Literacy: Communication & Collaboration
# 3  (BDLCC) Basic Digital Literacy: Communication & Collaboration
# 4  (BDLCC) Basic Digital Literacy: Communication & Collaboration
#
#                                                    course  rating  \
# 0          BDLCC3: Communicate & Collaborate with Agility       5
# 1  BDLCC1: Communicate & Collaborate with the Right Tools       5
# ...

# %%
shuffled.to_csv("shuffled_cc.csv")

# %% [markdown]
# ## 2. Cyber & Data Security

# %%
cd = df[df.course.str.contains("BDLCD")]
cd
# Out:
#                                            agency agency_short  \
# 1                       Housing Development Board          HDB
# 2                       Housing Development Board          HDB
# 9                       Housing Development Board          HDB
# 11                      Housing Development Board          HDB
# 26                      Housing Development Board          HDB
# ...                                           ...          ...
# 33381                       Civil Service College          CSC
# 39560                Government Technology Agency      GOVTECH
# 48637  Smart Nation And Digital Government Office        SNDGO
# 48716                Government Technology Agency      GOVTECH
# 49138                       Civil Service College          CSC
#
#                                                          tag  \
# 1                                    Prototype Testing Space
# 2      (BDLCD) Basic Digital Literacy: Cyber & Data Security
# ...

# %%
## drop rows with empty comments
cd.dropna(subset=['comment'], inplace=True)
cd
# Out:
# C:\Users\Boon Kong\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                     agency agency_short  \
# 11               Housing Development Board          HDB
# 32               Housing Development Board          HDB
# 53               Housing Development Board          HDB
# 58               Housing Development Board          HDB
# 64               Housing Development Board          HDB
# ...                                    ...          ...
# 33249                  Ministry of Defence       MINDEF
# 33254  Immigration & Checkpoints Authority          MHA
# 33306         Government Technology Agency      GOVTECH
# 33354               National Library Board          NLB
# ...

# %%
# shuffle the data to randomize it
shuffled = shuffle(cd)
shuffled.reset_index(inplace=True, drop=True)
shuffled.to_csv("shuffled_cd.csv")

# %% [markdown]
# ## 3. Information Literacy & Data Intelligence

# %%
bdlid = df[df.course.str.contains("BDLID")]
bdlid
# Out:
#                                      agency agency_short  \
# 5                 Housing Development Board          HDB
# 15                Housing Development Board          HDB
# 23      Immigration & Checkpoints Authority          MHA
# 28      Immigration & Checkpoints Authority          MHA
# 36                Housing Development Board          HDB
# ...                                     ...          ...
# 157075              Public Service Division          PSD
# 157076              Public Service Division          PSD
# 157077              Public Service Division          PSD
# 157290                Civil Service College          CSC
# 158156                Civil Service College          CSC
#
#                                                                                tag  \
# 5                 (BDLID) Basic Digital Literacy: Information Literacy & Data Inte
# 15                (BDLID) Basic Digital Literacy: Information Literacy & Data Inte
# ...

# %%
## drop rows with empty comments
bdlid.dropna(subset=['comment'], inplace=True)
bdlid
# Out:
# C:\Users\Boon Kong\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      agency agency_short  \
# 5                 Housing Development Board          HDB
# 15                Housing Development Board          HDB
# 23      Immigration & Checkpoints Authority          MHA
# 28      Immigration & Checkpoints Authority          MHA
# 36                Housing Development Board          HDB
# ...                                     ...          ...
# 156632            Housing Development Board          HDB
# 156636            Housing Development Board          HDB
# 156638            Housing Development Board          HDB
# 157075              Public Service Division          PSD
# ...

# %%
# shuffle the data to randomize it
shuffled = shuffle(bdlid)
shuffled.reset_index(inplace=True, drop=True)
shuffled.to_csv("shuffled_id.csv")

# %% [markdown]
# ## 4. Technology Literacy

# %%
tl = df[df.course.str.contains("BDLTL")]
tl
# Out:
#                                      agency agency_short  \
# 8       Immigration & Checkpoints Authority          MHA
# 12      Immigration & Checkpoints Authority          MHA
# 18      Immigration & Checkpoints Authority          MHA
# 21                Housing Development Board          HDB
# 24                   National Youth Council         MCCY
# ...                                     ...          ...
# 172595                Civil Service College          CSC
# 172598                Civil Service College          CSC
# 172600         Government Technology Agency      GOVTECH
# 172601                Civil Service College          CSC
# 172602                Civil Service College          CSC
#
#                                                         tag  \
# 8       (BDLTL) Basic Digital Literacy: Technology Literacy
# 12      (BDLTL) Basic Digital Literacy: Technology Literacy
# 18      (BDLTL) Basic Digital Literacy: Technology Literacy
# ...

# %%
## drop rows with empty comments
tl.dropna(subset=['comment'], inplace=True)
tl
# Out:
# C:\Users\Boon Kong\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           agency agency_short  \
# 8            Immigration & Checkpoints Authority          MHA
# 12           Immigration & Checkpoints Authority          MHA
# 18           Immigration & Checkpoints Authority          MHA
# 21                     Housing Development Board          HDB
# 29           Immigration & Checkpoints Authority          MHA
# ...                                          ...          ...
# 172584                       Temasek Polytechnic           TP
# 172585  Maritime And Port Authority Of Singapore          MPA
# 172586  Maritime And Port Authority Of Singapore          MPA
# ...

# %%
# shuffle the data to randomize it
shuffled = shuffle(tl)
shuffled.reset_index(inplace=True, drop=True)
shuffled.to_csv("shuffled_tl.csv")

# %% [markdown]
# ### now i will label all these csv files i saved

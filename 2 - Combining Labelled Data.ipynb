# %% [markdown]
# # Load data

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import re
import nltk

# %%
# did manual labelling prior to this
# the codes below are to check if there are equal entries of AOI/no AOI
# and equal entries of content/design/technical from each module

# %% [markdown]
# ## 1. C & C

# %%
labelled_cc = pd.read_csv('labelled_cc.csv')
labelled_cc.head()
# Out:
#    Unnamed: 0                            agency agency_short  \
# 0           0  Institute Of Technical Education          ITE
# 1           1       National Environment Agency          NEA
# 2           2         Health Sciences Authority          HSA
# 3           3  Institute Of Technical Education          ITE
# 4           4      Central Provident Fund Board          CPF
#
#                                                  tag  \
# 0  (BDLCC) Basic Digital Literacy: Communication ...
# 1  (BDLCC) Basic Digital Literacy: Communication ...
# 2  (BDLCC) Basic Digital Literacy: Communication ...
# 3  (BDLCC) Basic Digital Literacy: Communication ...
# 4  (BDLCC) Basic Digital Literacy: Communication ...
#
#                                               course  rating  \
# 0  BDLCC1: Communicate & Collaborate with the Rig...       5
# 1  BDLCC1: Communicate & Collaborate with the Rig...       5
# 2  BDLCC1: Communicate & Collaborate with the Rig...       5
# ...

# %%
## make sure labelled 200 y data

y = labelled_cc[labelled_cc['aoi'] == 'y']
y
# Out:
#       Unnamed: 0                                       agency agency_short  \
# 15            15             Ministry of Defence Headquarters       MINDEF
# 22            22             Institute Of Technical Education          ITE
# 63            63                  National Environment Agency          NEA
# 84            84                         Ngee Ann Polytechnic           NP
# 106          106                         Ngee Ann Polytechnic           NP
# ...          ...                                          ...          ...
# 3852        3852             Ministry of Defence Headquarters       MINDEF
# 3901        3901  Singapore Examinations And Assessment Board         SEAB
# 3911        3911                         Ngee Ann Polytechnic           NP
# 3960        3960                         Ngee Ann Polytechnic           NP
# 3969        3969                      National Heritage Board          NHB
#
#                                                     tag  \
# ...

# %%
## make sure labelled 200 n data

n = labelled_cc[labelled_cc['aoi'] == 'n']
n
# Out:
#      Unnamed: 0                            agency agency_short  \
# 0             0  Institute Of Technical Education          ITE
# 1             1       National Environment Agency          NEA
# 2             2         Health Sciences Authority          HSA
# 3             3  Institute Of Technical Education          ITE
# 4             4      Central Provident Fund Board          CPF
# ..          ...                               ...          ...
# 906         906      Central Provident Fund Board          CPF
# 910         910                 Singapore Customs          MOF
# 914         914  Institute Of Technical Education          ITE
# 916         916      Central Provident Fund Board          CPF
# 920         920  Ministry of Defence Headquarters       MINDEF
#
#                                                    tag  \
# 0    (BDLCC) Basic Digital Literacy: Communication ...
# 1    (BDLCC) Basic Digital Literacy: Communication ...
# ...

# %%
c = labelled_cc[labelled_cc['topic'] == 'c']
c
# Out:
#      Unnamed: 0                            agency agency_short  \
# 0             0  Institute Of Technical Education          ITE
# 3             3  Institute Of Technical Education          ITE
# 4             4      Central Provident Fund Board          CPF
# 8             8       National Environment Agency          NEA
# 10           10         Housing Development Board          HDB
# ..          ...                               ...          ...
# 721         721         Singapore Medical Council          SMC
# 741         741      Central Provident Fund Board          CPF
# 757         757  Institute Of Technical Education          ITE
# 765         765              Ministry Of Manpower          MOM
# 781         781       National Environment Agency          NEA
#
#                                                    tag  \
# 0    (BDLCC) Basic Digital Literacy: Communication ...
# 3    (BDLCC) Basic Digital Literacy: Communication ...
# ...

# %%
d = labelled_cc[labelled_cc['topic'] == 'd']
d
# Out:
#       Unnamed: 0                            agency agency_short  \
# 15            15  Ministry of Defence Headquarters       MINDEF
# 72            72            SkillsFuture Singapore          SSG
# 117          117       National Environment Agency          NEA
# 175          175              Ngee Ann Polytechnic           NP
# 243          243               Ministry of Defence       MINDEF
# ...          ...                               ...          ...
# 2750        2750       National Environment Agency          NEA
# 2757        2757          Auditor-General's Office          AGO
# 2812        2812                   JTC Corporation          JTC
# 2864        2864         Housing Development Board          HDB
# 2924        2924      Central Provident Fund Board          CPF
#
#                                                     tag  \
# 15    (BDLCC) Basic Digital Literacy: Communication ...
# 72    (BDLCC) Basic Digital Literacy: Communication ...
# ...

# %%
t = labelled_cc[labelled_cc['topic'] == 't']
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 187 to 3797
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60 non-null     int64
#  1   agency        60 non-null     object
#  2   agency_short  60 non-null     object
#  3   tag           60 non-null     object
#  4   course        60 non-null     object
#  5   rating        60 non-null     int64
#  6   comment       60 non-null     object
#  7   aoi           55 non-null     object
#  8   topic         60 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 4.7+ KB

# %% [markdown]
# ## 2. C & D

# %%
labelled_cd = pd.read_csv('labelled_cd.csv')
labelled_cd.head()
# Out:
#    Unnamed: 0                     agency agency_short  \
# 0           0  Housing Development Board          HDB
# 1           1       People's Association           PA
# 2           2   Land Transport Authority          LTA
# 3           3   Singapore Prison Service          MHA
# 4           4  Housing Development Board          HDB
#
#                                                  tag                   course  \
# 0                            Prototype Testing Space  BDLCD2: Data Security
# 1  (BDLCD) Basic Digital Literacy: Cyber & Data S...  BDLCD1: Cyber Security
# 2                            Prototype Testing Space  BDLCD2: Data Security
# 3  (BDLCD) Basic Digital Literacy: Cyber & Data S...  BDLCD1: Cyber Security
# 4                            Prototype Testing Space  BDLCD2: Data Security
#
#    rating                  comment  aoi topic
# 0       4                     Good  NaN   NaN
# 1       5    Good and informative     n     c
# ...

# %%
y = labelled_cd[labelled_cd['aoi'] == 'y']
y
# Out:
#       Unnamed: 0                                 agency agency_short  \
# 5              5              Housing Development Board          HDB
# 19            19                    Temasek Polytechnic           TP
# 20            20              Housing Development Board          HDB
# 22            22            National Environment Agency          NEA
# 47            47               Singapore Prison Service          MHA
# ...          ...                                    ...          ...
# 2432        2432                                  Vital          MOF
# 2459        2459              Housing Development Board          HDB
# 2469        2469              Housing Development Board          HDB
# 2487        2487               Department Of Statistics          MTI
# 2503        2503  Inland Revenue Authority Of Singapore         IRAS
#
#                                                     tag  \
# 5                               Prototype Testing Space
# ...

# %%
n = labelled_cd[labelled_cd['aoi'] == 'n']
n
# Out:
#      Unnamed: 0                                 agency agency_short  \
# 1             1                   People's Association           PA
# 4             4              Housing Development Board          HDB
# 7             7  Inland Revenue Authority Of Singapore         IRAS
# 8             8              Housing Development Board          HDB
# 10           10               Land Transport Authority          LTA
# ..          ...                                    ...          ...
# 768         768    Building And Construction Authority          BCA
# 769         769              Housing Development Board          HDB
# 786         786               Land Transport Authority          LTA
# 787         787                    Temasek Polytechnic           TP
# 789         789              Housing Development Board          HDB
#
#                                                    tag  \
# 1    (BDLCD) Basic Digital Literacy: Cyber & Data S...
# ...

# %%
c = labelled_cd[labelled_cd['topic'] == 'c']
c
# Out:
#       Unnamed: 0                               agency agency_short  \
# 1              1                 People's Association           PA
# 4              4            Housing Development Board          HDB
# 5              5            Housing Development Board          HDB
# 8              8            Housing Development Board          HDB
# 10            10             Land Transport Authority          LTA
# ...          ...                                  ...          ...
# 748          748             Land Transport Authority          LTA
# 763          763     Ministry of Defence Headquarters       MINDEF
# 764          764               Singapore Police Force          MHA
# 767          767             Land Transport Authority          LTA
# 1943        1943  Immigration & Checkpoints Authority          MHA
#
#                                                     tag  \
# 1     (BDLCD) Basic Digital Literacy: Cyber & Data S...
# ...

# %%
d = labelled_cd[labelled_cd['topic'] == 'd']
d
# Out:
#       Unnamed: 0                                 agency agency_short  \
# 19            19                    Temasek Polytechnic           TP
# 20            20              Housing Development Board          HDB
# 23            23  Inland Revenue Authority Of Singapore         IRAS
# 61            61                Singapore Tourism Board          STB
# 65            65              Housing Development Board          HDB
# ...          ...                                    ...          ...
# 2111        2111              Housing Development Board          HDB
# 2112        2112    Immigration & Checkpoints Authority          MHA
# 2169        2169               Land Transport Authority          LTA
# 2360        2360              Housing Development Board          HDB
# 2425        2425            Ministry of Foreign Affairs          MFA
#
#                                                     tag  \
# 19    (BDLCD) Basic Digital Literacy: Cyber & Data S...
# ...

# %%
t = labelled_cd[labelled_cd['topic'] == 't']
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 22 to 2469
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    23 non-null     int64
#  1   agency        23 non-null     object
#  2   agency_short  23 non-null     object
#  3   tag           23 non-null     object
#  4   course        23 non-null     object
#  5   rating        23 non-null     int64
#  6   comment       23 non-null     object
#  7   aoi           21 non-null     object
#  8   topic         23 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 1.8+ KB

# %% [markdown]
# ## 3. I & D

# %%
labelled_id = pd.read_csv('labelled_id.csv')
labelled_id.head()
# Out:
#    Unnamed: 0                               agency agency_short  \
# 0           0            Housing Development Board          HDB
# 1           1     Institute Of Technical Education          ITE
# 2           2          National Environment Agency          NEA
# 3           3  Immigration & Checkpoints Authority          MHA
# 4           4             Singapore Land Authority          SLA
#
#                                                  tag  \
# 0  (BDLID) Basic Digital Literacy: Information Li...
# 1  (BDLID) Basic Digital Literacy: Information Li...
# 2  (BDLID) Basic Digital Literacy: Information Li...
# 3  (BDLID) Basic Digital Literacy: Information Li...
# 4  (BDLID) Basic Digital Literacy: Information Li...
#
#                                               course  rating  \
# 0             BDLID5: Boost Your Data Visualisations       5
# 1  BDLID3: Introduction to Information Literacy &...       5
# 2  BDLID1: Upskilling Yourself Personally & Profe...       4
# ...

# %%
y = labelled_id[labelled_id['aoi'] == 'y']
y
# Out:
#       Unnamed: 0                            agency agency_short  \
# 5              5      Central Provident Fund Board          CPF
# 9              9             Singapore Polytechnic           SP
# 32            32            National Youth Council         MCCY
# 42            42             Singapore Polytechnic           SP
# 86            86      Central Provident Fund Board          CPF
# ...          ...                               ...          ...
# 4894        4894  Institute Of Technical Education          ITE
# 4895        4895       National Environment Agency          NEA
# 4910        4910      Central Provident Fund Board          CPF
# 4917        4917              Ngee Ann Polytechnic           NP
# 7685        7685      Central Provident Fund Board          CPF
#
#                                                     tag  \
# 5     (BDLID) Basic Digital Literacy: Information Li...
# 9     (BDLID) Basic Digital Literacy: Information Li...
# ...

# %%
n = labelled_id[labelled_id['aoi'] == 'n']
n
# Out:
#       Unnamed: 0                               agency agency_short  \
# 0              0            Housing Development Board          HDB
# 1              1     Institute Of Technical Education          ITE
# 2              2          National Environment Agency          NEA
# 3              3  Immigration & Checkpoints Authority          MHA
# 4              4             Singapore Land Authority          SLA
# ...          ...                                  ...          ...
# 3337        3337             Singapore Land Authority          SLA
# 3342        3342          National Environment Agency          NEA
# 3343        3343          National Environment Agency          NEA
# 3354        3354         Central Provident Fund Board          CPF
# 4848        4848             Land Transport Authority          LTA
#
#                                                     tag  \
# 0     (BDLID) Basic Digital Literacy: Information Li...
# ...

# %%
c = labelled_id[labelled_id['topic'] == 'c']
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 9 to 7330
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    301 non-null    int64
#  1   agency        301 non-null    object
#  2   agency_short  301 non-null    object
#  3   tag           301 non-null    object
#  4   course        301 non-null    object
#  5   rating        301 non-null    int64
#  6   comment       301 non-null    object
#  7   aoi           89 non-null     object
#  8   topic         301 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 23.5+ KB

# %%
d = labelled_id[labelled_id['topic'] == 'd']
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 42 to 7470
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    300 non-null    int64
#  1   agency        300 non-null    object
#  2   agency_short  300 non-null    object
#  3   tag           300 non-null    object
#  4   course        300 non-null    object
#  5   rating        300 non-null    int64
#  6   comment       300 non-null    object
#  7   aoi           85 non-null     object
#  8   topic         300 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 23.4+ KB

# %%
t = labelled_id[labelled_id['topic'] == 't']
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 104 to 9428
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    300 non-null    int64
#  1   agency        300 non-null    object
#  2   agency_short  300 non-null    object
#  3   tag           300 non-null    object
#  4   course        300 non-null    object
#  5   rating        300 non-null    int64
#  6   comment       300 non-null    object
#  7   aoi           156 non-null    object
#  8   topic         300 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 23.4+ KB

# %% [markdown]
# ## 4. TL

# %%
labelled_tl = pd.read_csv('labelled_tl.csv')
labelled_tl.head()
# Out:
#    Unnamed: 0                                       agency agency_short  \
# 0           0                          Nanyang Polytechnic          NYP
# 1           1                    Housing Development Board          HDB
# 2           2  Judiciary, Supreme and Family Justice Court     SUPCOURT
# 3           3             Institute Of Technical Education          ITE
# 4           4                         Ministry Of Manpower          MOM
#
#                                                  tag  \
# 0  (BDLTL) Basic Digital Literacy: Technology Lit...
# 1  (BDLTL) Basic Digital Literacy: Technology Lit...
# 2  (BDLTL) Basic Digital Literacy: Technology Lit...
# 3  (BDLTL) Basic Digital Literacy: Technology Lit...
# 4  (BDLTL) Basic Digital Literacy: Technology Lit...
#
#                                              course  rating  \
# 0                  BDLTL2: Global Technology Trends       4
# 1        BDLTL3: Digital Tools that Support My Work       3
# ...

# %%
y = labelled_tl[labelled_tl['aoi'] == 'y']
y
# Out:
#       Unnamed: 0                            agency agency_short  \
# 3              3  Institute Of Technical Education          ITE
# 6              6             Ministry Of Education          MOE
# 16            16            Health Promotion Board          HPB
# 19            19            Public Utilities Board          PUB
# 63            63       National Environment Agency          NEA
# ...          ...                               ...          ...
# 1831        1831              Ngee Ann Polytechnic           NP
# 1836        1836                 Singapore Customs          MOF
# 1842        1842              Ministry Of Manpower          MOM
# 1843        1843   Monetary Authority Of Singapore          MAS
# 1846        1846              Ngee Ann Polytechnic           NP
#
#                                                     tag  \
# 3     (BDLTL) Basic Digital Literacy: Technology Lit...
# 6     (BDLTL) Basic Digital Literacy: Technology Lit...
# ...

# %%
n = labelled_tl[labelled_tl['aoi'] == 'n']
n
# Out:
#      Unnamed: 0                                       agency agency_short  \
# 0             0                          Nanyang Polytechnic          NYP
# 1             1                    Housing Development Board          HDB
# 2             2  Judiciary, Supreme and Family Justice Court     SUPCOURT
# 4             4                         Ministry Of Manpower          MOM
# 5             5             Institute Of Technical Education          ITE
# ..          ...                                          ...          ...
# 690         690        Inland Revenue Authority Of Singapore         IRAS
# 693         693                         Ngee Ann Polytechnic           NP
# 700         700                         People's Association           PA
# 705         705                  National Environment Agency          NEA
# 708         708                         Republic Polytechnic           RP
#
#                                                    tag  \
# ...

# %%
c = labelled_tl[labelled_tl['topic'] == 'c']
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 2758
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    200 non-null    int64
#  1   agency        200 non-null    object
#  2   agency_short  200 non-null    object
#  3   tag           200 non-null    object
#  4   course        200 non-null    object
#  5   rating        200 non-null    int64
#  6   comment       200 non-null    object
#  7   aoi           99 non-null     object
#  8   topic         200 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 15.6+ KB

# %%
d = labelled_tl[labelled_tl['topic'] == 'd']
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 6 to 3041
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    200 non-null    int64
#  1   agency        200 non-null    object
#  2   agency_short  200 non-null    object
#  3   tag           200 non-null    object
#  4   course        200 non-null    object
#  5   rating        200 non-null    int64
#  6   comment       200 non-null    object
#  7   aoi           87 non-null     object
#  8   topic         200 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 15.6+ KB

# %%
t = labelled_tl[labelled_tl['topic'] == 't']
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 88 to 4672
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    200 non-null    int64
#  1   agency        200 non-null    object
#  2   agency_short  200 non-null    object
#  3   tag           200 non-null    object
#  4   course        200 non-null    object
#  5   rating        200 non-null    int64
#  6   comment       200 non-null    object
#  7   aoi           68 non-null     object
#  8   topic         200 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 15.6+ KB

# %% [markdown]
# # Combine data

# %%
frames = [labelled_cc, labelled_cd, labelled_id, labelled_tl]

# %%
result = pd.concat(frames, axis=0, ignore_index=True)
result
# Out:
#        Unnamed: 0                            agency agency_short  \
# 0               0  Institute Of Technical Education          ITE
# 1               1       National Environment Agency          NEA
# 2               2         Health Sciences Authority          HSA
# 3               3  Institute Of Technical Education          ITE
# 4               4      Central Provident Fund Board          CPF
# ...           ...                               ...          ...
# 23334        6971         Housing Development Board          HDB
# 23335        6972      Central Provident Fund Board          CPF
# 23336        6973         Housing Development Board          HDB
# 23337        6974               Temasek Polytechnic           TP
# 23338        6975         Housing Development Board          HDB
#
#                                                      tag  \
# 0      (BDLCC) Basic Digital Literacy: Communication ...
# 1      (BDLCC) Basic Digital Literacy: Communication ...
# ...

# %%
result.drop(result.columns[0], axis=1, inplace=True)
result.head()
# Out:
#                              agency agency_short  \
# 0  Institute Of Technical Education          ITE
# 1       National Environment Agency          NEA
# 2         Health Sciences Authority          HSA
# 3  Institute Of Technical Education          ITE
# 4      Central Provident Fund Board          CPF
#
#                                                  tag  \
# 0  (BDLCC) Basic Digital Literacy: Communication ...
# 1  (BDLCC) Basic Digital Literacy: Communication ...
# 2  (BDLCC) Basic Digital Literacy: Communication ...
# 3  (BDLCC) Basic Digital Literacy: Communication ...
# 4  (BDLCC) Basic Digital Literacy: Communication ...
#
#                                               course  rating  \
# 0  BDLCC1: Communicate & Collaborate with the Rig...       5
# 1  BDLCC1: Communicate & Collaborate with the Rig...       5
# 2  BDLCC1: Communicate & Collaborate with the Rig...       5
# 3     BDLCC3: Communicate & Collaborate with Agility       5
# ...

# %%
result.to_csv('total_labelled.csv')
